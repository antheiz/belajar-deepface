# %% [markdown]
# <a href="https://colab.research.google.com/github/antheiz/belajar-deepface/blob/master/Facial-Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install deepface

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
models = ["VGG-Face", "Facenet", "Facenet512", "OpenFace", "DeepFace", "DeepID", "ArcFace", "Dlib"]

# %%
img1_path = 'images/1.jpg'
img2_path = 'images/4.jpg'

img1 = DeepFace.detectFace(img1_path)
img2 = DeepFace.detectFace(img2_path)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
result = DeepFace.verify(img1_path = img1_path, img2_path = img2_path, model_name = models[0])

# %%
result
# Out:
# {'detector_backend': 'opencv',
#  'distance': 0.27559218179253187,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'threshold': 0.4,
#  'verified': True}

# %%
result
# Out:
# {'detector_backend': 'opencv',
#  'distance': 0.27559218179253187,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'threshold': 0.4,
#  'verified': True}

# %%
df = DeepFace.find(img_path = 'images/1.jpg', db_path = 'images' )
# Out:
# WARNING: Representations for images in  images  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  5  representations found in  representations_vgg_face.pkl
# find function lasts  1.7848446369171143  seconds

# %%
df
# Out:
#         identity  VGG-Face_cosine
# 0  images//1.jpg     4.440892e-16
# 1  images//4.jpg     2.755922e-01
# 2  images//2.jpg     2.776512e-01

# %%
backends = ['opencv', 'ssd', 'dlib', 'mtcnn', 'retinaface', 'mediapipe']

# %%
demography = DeepFace.analyze(img_path = "images/3.jpg", detector_backend = backends[4])
# Out:
# Action: race: 100%|██████████| 4/4 [00:14<00:00,  3.74s/it]

# %%
demography
# Out:
# {'age': 45,
#  'dominant_emotion': 'happy',
#  'dominant_race': 'latino hispanic',
#  'emotion': {'angry': 1.738481192063513e-15,
#   'disgust': 8.205709497279816e-31,
#   'fear': 1.975567210356795e-19,
#   'happy': 100.0,
#   'neutral': 1.0958675078498459e-07,
#   'sad': 4.684653357643837e-14,
#   'surprise': 2.3281962295562675e-11},
#  'gender': 'Man',
#  'race': {'asian': 7.527779787778854,
#   'black': 12.46945932507515,
#   'indian': 11.391094326972961,
#   'latino hispanic': 35.24364531040192,
#   'middle eastern': 12.179087847471237,
#   'white': 21.188928186893463},
#  'region': {'h': 900, 'w': 634, 'x': 290, 'y': 160}}

# %%
demography
# Out:
# {'age': 33,
#  'dominant_emotion': 'happy',
#  'dominant_race': 'black',
#  'emotion': {'angry': 0.023637556296307594,
#   'disgust': 1.9871915224456416e-07,
#   'fear': 0.0025561814254615456,
#   'happy': 97.47369885444641,
#   'neutral': 2.454959601163864,
#   'sad': 0.04331327218096703,
#   'surprise': 0.001837087984313257},
#  'gender': 'Man',
#  'race': {'asian': 1.5343244257042426e-07,
#   'black': 99.99999403953517,
#   'indian': 6.249563372940779e-06,
#   'latino hispanic': 1.1129343444051895e-06,
#   'middle eastern': 4.3555846206771094e-12,
#   'white': 3.7584190389043214e-11},
#  'region': {'h': 792, 'w': 595, 'x': 204, 'y': 194}}

# %%
embedding = DeepFace.represent(img_path = "images/1.jpg", model_name = models[1])

# %%
embedding
# Out:
# [-0.3269735276699066,
#  0.6799095869064331,
#  -1.1202926635742188,
#  0.21292170882225037,
#  -1.3690088987350464,
#  -1.1055922508239746,
#  -0.03785954788327217,
#  0.5159978866577148,
#  -1.6287144422531128,
#  0.7229957580566406,
#  -0.5136480331420898,
#  1.7511796951293945,
#  0.6107921004295349,
#  -0.8712036609649658,
#  0.27387237548828125,
#  0.7288851737976074,
#  -0.36984875798225403,
#  -1.0479024648666382,
#  -0.35465070605278015,
#  -1.6501173973083496,
#  0.04415556788444519,
#  -1.1450673341751099,
#  -1.0622472763061523,
#  0.4403579533100128,
#  -0.5247547626495361,
#  -1.4128509759902954,
#  -0.9029833078384399,
#  1.3542283773422241,
#  -0.7748908400535583,
#  -1.0401195287704468,
#  -0.6932322978973389,
#  0.017069794237613678,
#  0.5029338598251343,
#  0.24484989047050476,
#  0.05838010460138321,
#  -1.7408705949783325,
#  -1.012269377708435,
#  -1.4173798561096191,
#  0.10898736119270325,
#  -0.1633828580379486,
#  -0.22526898980140686,
# ...
