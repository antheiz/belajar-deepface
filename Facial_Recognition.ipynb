# %% [markdown]
# <a href="https://colab.research.google.com/github/antheiz/belajar-deepface/blob/master/Facial_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install deepface
# Out:
# ...
#      |████████████████████████████████| 63 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 16.7 MB/s
# ...
#      |████████████████████████████████| 462 kB 45.3 MB/s
# ...

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
models = ["VGG-Face", "Facenet", "Facenet512", "OpenFace", "DeepFace", "DeepID", "ArcFace", "Dlib"]

# %%
img1_path = "img/1.jpg"
img2_path = "img/2.jpg"

img1 = DeepFace.detectFace(img1_path)
img2 = DeepFace.detectFace(img2_path)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img_more1 = "img/3.jpg"
img_more2 = "5.jpg"
img_moremore1 = DeepFace.detectFace(img_more1)
img_moremore2 = DeepFace.detectFace(img_more2)

# %%
plt.imshow(img_moremore1)

# %%
plt.imshow(img_moremore2)

# %%
result = DeepFace.verify(img1_path= img1_path, img2_path= img2_path,  model_name = models[6])

# %%
result
# Out:
# {'detector_backend': 'opencv',
#  'distance': 0.2422287485961192,
#  'model': 'ArcFace',
#  'similarity_metric': 'cosine',
#  'threshold': 0.68,
#  'verified': True}

# %%
result
# Out:
# {'detector_backend': 'opencv',
#  'distance': 0.27765124361199944,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'threshold': 0.4,
#  'verified': True}

# %%
result
# Out:
# {'detector_backend': 'opencv',
#  'distance': 0.1441668870878111,
#  'model': 'Facenet',
#  'similarity_metric': 'cosine',
#  'threshold': 0.4,
#  'verified': True}

# %%
df = DeepFace.find(img_path = '5.jpg', db_path = 'img/')
# Out:
# WARNING: Representations for images in  img/  folder were previously stored in  representations_vgg_face.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  3  representations found in  representations_vgg_face.pkl
# find function lasts  1.0158638954162598  seconds

# %%
df
# Out:
#      identity  VGG-Face_cosine
# 0  img//3.jpg          0.16814
